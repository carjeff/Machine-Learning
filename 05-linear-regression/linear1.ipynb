# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sse import loss
from sklearn.datasets import make_regression
rx, ry = make_regression(
    n_samples=100,
    n_features=1,
    noise=1,
    bias=1
)

# %%
w0 = np.linspace(-10,10,100)
w1 = np.linspace(-10,10,100)

# %%
errors = []
for w,n in zip(w0,w1):
    errors.append(loss(rx,ry,[w,n]))
error = np.array(errors)

# %%
_w0,_w1 = np.meshgrid(w0,w1)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')
ax.plot_surface(X=_w0,Y=_w1,Z=error)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-9bac53c758b5> in <module>
#       1 fig = plt.figure(figsize=(10, 10))
#       2 ax = fig.gca(projection='3d')
# ----> 3 ax.plot_surface(X=_w0,Y=_w1,Z=error)
#
# E:\anaconda\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1612
#    1613         if Z.ndim != 2:
# -> 1614             raise ValueError("Argument Z must be 2-dimensional.")
#    1615         if np.any(np.isnan(Z)):
#    1616             cbook._warn_external(
#
# ValueError: Argument Z must be 2-dimensional.
