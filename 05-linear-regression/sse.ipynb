# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from sse import loss

# %%
from sklearn.datasets import make_regression
rx, ry = make_regression(
    n_samples=100,
    n_features=1,
    noise=1,
    bias=1
)

# %%
plt.grid()
plt.scatter(rx, ry)
x = np.linspace(-3,3,100)
w=[0,63]
y = w[0] + x * w[1]
plt.plot(x, y, '-r', label=f'y={w[1]}x+{w[0]}')

# %%
loss(rx, ry, w)
# Out:
# 203.66846785493718

# %%
errors=[]
samples = np.linspace(40, 90)
for n in samples:
    errors.append(loss(rx, ry, [0, n]))
errors=pd.Series(errors)

# %%
errors
# Out:
# 0     41421.123815
# 1     37902.139992
# 2     34540.105828
# 3     31335.021323
# 4     28286.886476
# 5     25395.701289
# 6     22661.465761
# 7     20084.179892
# 8     17663.843682
# 9     15400.457130
# 10    13294.020238
# 11    11344.533005
# 12     9551.995430
# 13     7916.407515
# 14     6437.769259
# 15     5116.080661
# 16     3951.341723
# 17     2943.552443
# 18     2092.712823
# 19     1398.822862
# 20      861.882559
# 21      481.891916
# 22      258.850931
# 23      192.759606
# 24      283.617939
# 25      531.425932
# 26      936.183583
# 27     1497.890894
# 28     2216.547863
# 29     3092.154492
# 30     4124.710779
# 31     5314.216725
# 32     6660.672331
# 33     8164.077595
# 34     9824.432518
# 35    11641.737101
# 36    13615.991342
# 37    15747.195242
# 38    18035.348802
# 39    20480.452020
# 40    23082.504897
# 41    25841.507433
# 42    28757.459629
# 43    31830.361483
# 44    35060.212996
# 45    38447.014168
# 46    41990.764999
# 47    45691.465489
# 48    49549.115638
# 49    53563.715447
# dtype: float64

# %%
errors.shape
# Out:
# (50,)

# %%
plt.plot(samples, errors)

# %%
plt.grid()
plt.scatter(rx, ry)
x = np.linspace(-2,2)
w=[1,63]
y = w[0] + w[1] * x
plt.plot(x, y, '-r', label=f'y={w[1]}x+{w[0]}')

# %%
loss(rx,ry,w)
# Out:
# 85.20441492898946

# %%
errors=[]
samples = np.linspace(-20, 30)
for n in samples:
    errors.append(loss(rx, ry, [n, 63]))
errors=pd.Series(errors)

# %%
errors
# Out:
# 0     44572.949526
# 1     40372.517652
# 2     36380.332342
# 3     32596.393596
# 4     29020.701414
# 5     25653.255795
# 6     22494.056741
# 7     19543.104250
# 8     16800.398324
# 9     14265.938961
# 10    11939.726162
# 11     9821.759928
# 12     7912.040257
# 13     6210.567150
# 14     4717.340607
# 15     3432.360628
# 16     2355.627213
# 17     1487.140362
# 18      826.900074
# 19      374.906351
# 20      131.159192
# 21       95.658596
# 22      268.404565
# 23      649.397097
# 24     1238.636194
# 25     2036.121854
# 26     3041.854078
# 27     4255.832866
# 28     5678.058218
# 29     7308.530134
# 30     9147.248614
# 31    11194.213658
# 32    13449.425266
# 33    15912.883438
# 34    18584.588173
# 35    21464.539473
# 36    24552.737336
# 37    27849.181764
# 38    31353.872755
# 39    35066.810311
# 40    38987.994430
# 41    43117.425113
# 42    47455.102360
# 43    52001.026171
# 44    56755.196546
# 45    61717.613485
# 46    66888.276988
# 47    72267.187055
# 48    77854.343685
# 49    83649.746880
# dtype: float64

# %%
plt.plot(samples, errors)
