# %%
from knn import load_data

# %%
X_train, X_test, y_train, y_test = load_data()

# %%
X_train.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 41                 4.5               2.3                1.3               0.3
# 92                 5.8               2.6                4.0               1.2
# 149                5.9               3.0                5.1               1.8
# 55                 5.7               2.8                4.5               1.3
# 20                 5.4               3.4                1.7               0.2

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
X_test.iloc[0,0]
# Out:
# 5.4

# %%
X_train.hist(figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002BB22032390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BB222CF7F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002BB2230C1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002BB22339B70>]],
#       dtype=object)

# %%
for i in range(4):
    for j in range(4):
        x = X_train.iloc[:,i]
        y = X_train.iloc[:,j]
        if i != j:
            plt.scatter(x, y, marker='o',  c=y_train)
            plt.show()

# %%
y_test.hist()

# %%
from sklearn.datasets import load_breast_cancer

# %%
dataset = load_breast_cancer()

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
X, y = pd.DataFrame(dataset.data), pd.Series(dataset.target)
X.columns = dataset.feature_names
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True)

# %%
print(X_train)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 203        13.81         23.75           91.56      597.8          0.13230
# 137        11.43         15.39           73.06      399.8          0.09639
# 312        12.76         13.37           82.29      504.1          0.08794
# 145        11.90         14.65           78.11      432.8          0.11520
# 78         20.18         23.97          143.70     1245.0          0.12860
# ..           ...           ...             ...        ...              ...
# 182        15.70         20.31          101.20      766.6          0.09597
# 491        17.85         13.23          114.60      992.1          0.07838
# 231        11.32         27.08           71.76      395.7          0.06883
# 426        10.48         14.98           67.49      333.6          0.09816
# 212        28.11         18.47          188.50     2499.0          0.11420
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 203           0.17680         0.15580             0.091760         0.2251
# 137           0.06889         0.03503             0.028750         0.1734
# 312           0.07948         0.04052             0.025480         0.1601
# 145           0.12960         0.03710             0.030030         0.1995
# 78            0.34540         0.37540             0.160400         0.2906
# ..                ...             ...                  ...            ...
# 182           0.08799         0.06593             0.051890         0.1618
# 491           0.06217         0.04445             0.041780         0.1220
# 231           0.03813         0.01633             0.003125         0.1869
# 426           0.10130         0.06335             0.022180         0.1925
# 212           0.15160         0.32010             0.159500         0.1648
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 203                 0.07421  ...         19.20          41.85
# 137                 0.05865  ...         12.32          22.02
# 312                 0.06140  ...         14.19          16.40
# 145                 0.07839  ...         13.15          16.51
# 78                  0.08142  ...         23.37          31.72
# ..                      ...  ...           ...            ...
# 182                 0.05549  ...         20.11          32.82
# 491                 0.05243  ...         19.82          18.42
# 231                 0.05628  ...         12.08          33.75
# 426                 0.06915  ...         12.13          21.57
# 212                 0.05525  ...         28.11          18.47
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 203           128.50      1153.0           0.22260            0.52090
# 137            79.93       462.0           0.11900            0.16480
# 312            92.04       618.8           0.11940            0.22080
# 145            86.26       509.6           0.14240            0.25170
# 78            170.30      1623.0           0.16390            0.61640
# ..               ...         ...               ...                ...
# 182           129.30      1269.0           0.14140            0.35470
# 491           127.10      1210.0           0.09862            0.09976
# 231            79.82       452.3           0.09203            0.14320
# 426            81.41       440.4           0.13270            0.29960
# 212           188.50      2499.0           0.11420            0.15160
#
#      worst concavity  worst concave points  worst symmetry  \
# 203           0.4646               0.20130          0.4432
# 137           0.1399               0.08476          0.2676
# 312           0.1769               0.08411          0.2564
# 145           0.0942               0.06042          0.2727
# 78            0.7681               0.25080          0.5440
# ..               ...                   ...             ...
# 182           0.2902               0.15410          0.3437
# 491           0.1048               0.08341          0.1783
# 231           0.1089               0.02083          0.2849
# 426           0.2939               0.09310          0.3020
# 212           0.3201               0.15950          0.1648
#
#      worst fractal dimension
# 203                  0.10860
# 137                  0.06765
# 312                  0.08253
# 145                  0.10360
# 78                   0.09964
# ..                       ...
# 182                  0.08631
# 491                  0.05871
# 231                  0.07087
# 426                  0.09646
# 212                  0.05525
#
# [426 rows x 30 columns]
