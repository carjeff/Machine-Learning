# %%
from knn import load_data

# %%
X_train, X_test, y_train, y_test = load_data()

# %%
X_train.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 79                 5.7               2.6                3.5               1.0
# 103                6.3               2.9                5.6               1.8
# 20                 5.4               3.4                1.7               0.2
# 5                  5.4               3.9                1.7               0.4
# 148                6.2               3.4                5.4               2.3

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
X_test.iloc[0,0]
# Out:
# 6.7

# %%
X_train.hist(figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001654C1BBD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001654A018048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001654D4BCD88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001654D4F5E48>]],
#       dtype=object)

# %%
for i in range(4):
    for j in range(4):
        x = X_train.iloc[:,i]
        y = X_train.iloc[:,j]
        if i != j:
            plt.scatter(x, y, marker='o',  c=y_train)
            plt.show()

# %%
y_test.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E786F95688>]],
#       dtype=object)
